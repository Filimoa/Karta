# %%
#import necessary libraries
import numpy as np 
import pandas as pd
import plotly

import plotly.express as px

# %%
MAPBOX_TOKEN = 'pk.eyJ1Ijoic2VyamVzdGVyIiwiYSI6ImNqeWV0ZWZsNTE0ejEzbHM4dnk5eWU2Z2cifQ.530rMydViqZBXBwPp6oLeQ'

pd.set_option('display.max_columns', None)
# key goals

# create a super simple demo for colorado 
#

# %%
# !python -v
# Out:
# # installing zipimport hook
# import zipimport # builtin
# # installed zipimport hook
# # /Users/andreyfilimonov/anaconda2/lib/python2.7/site.pyc matches /Users/andreyfilimonov/anaconda2/lib/python2.7/site.py
# import site # precompiled from /Users/andreyfilimonov/anaconda2/lib/python2.7/site.pyc
# # /Users/andreyfilimonov/anaconda2/lib/python2.7/os.pyc matches /Users/andreyfilimonov/anaconda2/lib/python2.7/os.py
# import os # precompiled from /Users/andreyfilimonov/anaconda2/lib/python2.7/os.pyc
# import errno # builtin
# import posix # builtin
# # /Users/andreyfilimonov/anaconda2/lib/python2.7/posixpath.pyc matches /Users/andreyfilimonov/anaconda2/lib/python2.7/posixpath.py
# import posixpath # precompiled from /Users/andreyfilimonov/anaconda2/lib/python2.7/posixpath.pyc
# # /Users/andreyfilimonov/anaconda2/lib/python2.7/stat.pyc matches /Users/andreyfilimonov/anaconda2/lib/python2.7/stat.py
# import stat # precompiled from /Users/andreyfilimonov/anaconda2/lib/python2.7/stat.pyc
# # /Users/andreyfilimonov/anaconda2/lib/python2.7/genericpath.pyc matches /Users/andreyfilimonov/anaconda2/lib/python2.7/genericpath.py
# import genericpath # precompiled from /Users/andreyfilimonov/anaconda2/lib/python2.7/genericpath.pyc
# # /Users/andreyfilimonov/anaconda2/lib/python2.7/warnings.pyc matches /Users/andreyfilimonov/anaconda2/lib/python2.7/warnings.py
# import warnings # precompiled from /Users/andreyfilimonov/anaconda2/lib/python2.7/warnings.pyc
# # /Users/andreyfilimonov/anaconda2/lib/python2.7/linecache.pyc matches /Users/andreyfilimonov/anaconda2/lib/python2.7/linecache.py
# import linecache # precompiled from /Users/andreyfilimonov/anaconda2/lib/python2.7/linecache.pyc
# # /Users/andreyfilimonov/anaconda2/lib/python2.7/types.pyc matches /Users/andreyfilimonov/anaconda2/lib/python2.7/types.py
# import types # precompiled from /Users/andreyfilimonov/anaconda2/lib/python2.7/types.pyc
# # /Users/andreyfilimonov/anaconda2/lib/python2.7/UserDict.pyc matches /Users/andreyfilimonov/anaconda2/lib/python2.7/UserDict.py
# import UserDict # precompiled from /Users/andreyfilimonov/anaconda2/lib/python2.7/UserDict.pyc
# # /Users/andreyfilimonov/anaconda2/lib/python2.7/_abcoll.pyc matches /Users/andreyfilimonov/anaconda2/lib/python2.7/_abcoll.py
# import _abcoll # precompiled from /Users/andreyfilimonov/anaconda2/lib/python2.7/_abcoll.pyc
# # /Users/andreyfilimonov/anaconda2/lib/python2.7/abc.pyc matches /Users/andreyfilimonov/anaconda2/lib/python2.7/abc.py
# import abc # precompiled from /Users/andreyfilimonov/anaconda2/lib/python2.7/abc.pyc
# # /Users/andreyfilimonov/anaconda2/lib/python2.7/_weakrefset.pyc matches /Users/andreyfilimonov/anaconda2/lib/python2.7/_weakrefset.py
# import _weakrefset # precompiled from /Users/andreyfilimonov/anaconda2/lib/python2.7/_weakrefset.pyc
# import _weakref # builtin
# # /Users/andreyfilimonov/anaconda2/lib/python2.7/copy_reg.pyc matches /Users/andreyfilimonov/anaconda2/lib/python2.7/copy_reg.py
# import copy_reg # precompiled from /Users/andreyfilimonov/anaconda2/lib/python2.7/copy_reg.pyc
# # /Users/andreyfilimonov/anaconda2/lib/python2.7/traceback.pyc matches /Users/andreyfilimonov/anaconda2/lib/python2.7/traceback.py
# import traceback # precompiled from /Users/andreyfilimonov/anaconda2/lib/python2.7/traceback.pyc
# # /Users/andreyfilimonov/anaconda2/lib/python2.7/sysconfig.pyc matches /Users/andreyfilimonov/anaconda2/lib/python2.7/sysconfig.py
# import sysconfig # precompiled from /Users/andreyfilimonov/anaconda2/lib/python2.7/sysconfig.pyc
# # /Users/andreyfilimonov/anaconda2/lib/python2.7/re.pyc matches /Users/andreyfilimonov/anaconda2/lib/python2.7/re.py
# import re # precompiled from /Users/andreyfilimonov/anaconda2/lib/python2.7/re.pyc
# # /Users/andreyfilimonov/anaconda2/lib/python2.7/sre_compile.pyc matches /Users/andreyfilimonov/anaconda2/lib/python2.7/sre_compile.py
# import sre_compile # precompiled from /Users/andreyfilimonov/anaconda2/lib/python2.7/sre_compile.pyc
# import _sre # builtin
# # /Users/andreyfilimonov/anaconda2/lib/python2.7/sre_parse.pyc matches /Users/andreyfilimonov/anaconda2/lib/python2.7/sre_parse.py
# import sre_parse # precompiled from /Users/andreyfilimonov/anaconda2/lib/python2.7/sre_parse.pyc
# # /Users/andreyfilimonov/anaconda2/lib/python2.7/sre_constants.pyc matches /Users/andreyfilimonov/anaconda2/lib/python2.7/sre_constants.py
# import sre_constants # precompiled from /Users/andreyfilimonov/anaconda2/lib/python2.7/sre_constants.pyc
# dlopen("/Users/andreyfilimonov/anaconda2/lib/python2.7/lib-dynload/_locale.so", 2);
# import _locale # dynamically loaded from /Users/andreyfilimonov/anaconda2/lib/python2.7/lib-dynload/_locale.so
# # /Users/andreyfilimonov/anaconda2/lib/python2.7/_sysconfigdata.pyc matches /Users/andreyfilimonov/anaconda2/lib/python2.7/_sysconfigdata.py
# import _sysconfigdata # precompiled from /Users/andreyfilimonov/anaconda2/lib/python2.7/_sysconfigdata.pyc
# # /Users/andreyfilimonov/anaconda2/lib/python2.7/_osx_support.pyc matches /Users/andreyfilimonov/anaconda2/lib/python2.7/_osx_support.py
# import _osx_support # precompiled from /Users/andreyfilimonov/anaconda2/lib/python2.7/_osx_support.pyc
# # zipimport: found 10 names in /Users/andreyfilimonov/anaconda2/lib/python2.7/site-packages/pydot_ng-1.0.1.dev0-py2.7.egg
# import encodings # directory /Users/andreyfilimonov/anaconda2/lib/python2.7/encodings
# # /Users/andreyfilimonov/anaconda2/lib/python2.7/encodings/__init__.pyc matches /Users/andreyfilimonov/anaconda2/lib/python2.7/encodings/__init__.py
# import encodings # precompiled from /Users/andreyfilimonov/anaconda2/lib/python2.7/encodings/__init__.pyc
# # /Users/andreyfilimonov/anaconda2/lib/python2.7/codecs.pyc matches /Users/andreyfilimonov/anaconda2/lib/python2.7/codecs.py
# import codecs # precompiled from /Users/andreyfilimonov/anaconda2/lib/python2.7/codecs.pyc
# import _codecs # builtin
# # /Users/andreyfilimonov/anaconda2/lib/python2.7/encodings/aliases.pyc matches /Users/andreyfilimonov/anaconda2/lib/python2.7/encodings/aliases.py
# import encodings.aliases # precompiled from /Users/andreyfilimonov/anaconda2/lib/python2.7/encodings/aliases.pyc
# # /Users/andreyfilimonov/anaconda2/lib/python2.7/encodings/utf_8.pyc matches /Users/andreyfilimonov/anaconda2/lib/python2.7/encodings/utf_8.py
# import encodings.utf_8 # precompiled from /Users/andreyfilimonov/anaconda2/lib/python2.7/encodings/utf_8.pyc
# Python 2.7.16 |Anaconda, Inc.| (default, Mar 14 2019, 16:24:02)
# [GCC 4.2.1 Compatible Clang 4.0.1 (tags/RELEASE_401/final)] on darwin
# Type "help", "copyright", "credits" or "license" for more information.
# dlopen("/Users/andreyfilimonov/anaconda2/lib/python2.7/lib-dynload/readline.so", 2);
# import readline # dynamically loaded from /Users/andreyfilimonov/anaconda2/lib/python2.7/lib-dynload/readline.so
# >>>
# KeyboardInterrupt
# >>>
# >>>

# %%
df = pd.read_csv('skiCo.csv', encoding = "ISO-8859-1")

display(df.head())
# Out:
#    Unnamed: 0      lat      long      resort_name      continent country  \
# 0         199  39.6425  105.8719   arapahoe-basin  North America     USA
# 1         252  39.1823  106.8555  aspen-highlands  North America     USA
# 2         253      NaN       NaN   aspen-mountain  North America     USA
# 3         369  39.6042  106.5165     beaver-creek  North America     USA
# 4         577  39.4817  106.0384     breckenridge  North America     USA
#
#       state                                                url  altitude  \
# 0  Colorado  http://www.skiresort.info/ski-resort/arapahoe-...      3790
# 1  Colorado  http://www.skiresort.info/ski-resort/aspen-hig...      3559
# 2  Colorado  http://www.skiresort.info/ski-resort/aspen-mou...      3418
# 3  Colorado  http://www.skiresort.info/ski-resort/beaver-cr...      3488
# 4  Colorado  http://www.skiresort.info/ski-resort/breckenri...      3914
#
#    easy  medium  hard  Funicular  Circulating ropeway/gondola lift  chairlift  \
# 0  40.0    25.0  40.0        NaN                               NaN        0.0
# 1  24.3    40.5  70.2        NaN                               NaN        0.0
# 2   0.0    49.0  54.0        NaN                               0.0        0.0
# 3  28.5    64.5  57.0        NaN                               0.0        0.0
# 4  28.0    60.0  65.0        NaN                               0.0        0.0
#
#    T-bar lift/platter/button lift   Sunkid Moving Carpet  Adult  Youth  Child  \
# 0                              NaN                   NaN    100     85     52
# 1                              NaN                   NaN    169      0    112
# 2                              NaN                   NaN    169      0    112
# 3                              NaN                   NaN    189      0    130
# 4                              0.0                   0.0    164      0    107
#
#     Currency  ski_resort_size  num_runs  Lifts and cable cars   \
# 0  US Dollar              3.0       5.0                    3.0
# 1  US Dollar              4.0       5.0                    4.0
# 2  US Dollar              3.0       4.0                    4.0
# 3  US Dollar              4.0       5.0                    4.0
# 4  US Dollar              4.0       5.0                    4.0
#
#    Snow reliability   Slope preparation   Access, on-site parking   \
# 0                5.0                 4.0                       4.0
# 1                5.0                 4.0                       2.0
# 2                4.0                 5.0                       2.0
# 3                5.0                 5.0                       4.0
# 4                5.0                 4.0                       3.0
#
#    Orientation (trail map, information boards, sign-postings)   \
# 0                                                4.0
# 1                                                4.0
# 2                                                4.0
# 3                                                5.0
# 4                                                5.0
#
#    Cleanliness and hygiene   Environmentally friendly ski operation   \
# 0                       4.0                                      4.0
# 1                       4.0                                      4.0
# 2                       4.0                                      4.0
# 3                       4.0                                      3.0
# 4                       4.0                                      3.0
#
#    Friendliness of staff   Mountain restaurants, ski huts, gastronomy   \
# 0                     4.0                                          3.0
# 1                     5.0                                          4.0
# 2                     5.0                                          3.0
# 3                     5.0                                          4.0
# 4                     5.0                                          4.0
#
#    Aprs-ski   Accommodation offering directly at the slopes and lifts   \
# 0         2.0                                                1.0
# 1         3.0                                                4.0
# 2         4.0                                                4.0
# 3         4.0                                                5.0
# 4         4.0                                                5.0
#
#    Families and children   Beginners   Advanced skiers, freeriders   \
# 0                     3.0         3.0                           5.0
# 1                     2.0         3.0                           5.0
# 2                     1.0         1.0                           5.0
# 3                     5.0         5.0                           5.0
# 4                     5.0         5.0                           5.0
#
#    Snow parks   Cross-country skiing and trails   \
# 0          5.0                               1.0
# 1          2.0                               3.0
# 2          1.0                               3.0
# 3          5.0                               3.0
# 4          5.0                               3.0
#
#    Aerial tramway/reversible ropeway  Rope tow/beginner lift  People mover  \
# 0                                NaN                     NaN           0.0
# 1                                NaN                     NaN           NaN
# 2                                NaN                     NaN           NaN
# 3                                NaN                     NaN           0.0
# 4                                NaN                     NaN           0.0
#
#    Combined installation (gondola and chair)  Cog railway  \
# 0                                        NaN          NaN
# 1                                        NaN          NaN
# 2                                        NaN          NaN
# 3                                        0.0          NaN
# 4                                        NaN          NaN
#
#    Helicopter for Heli-skiing  Snow caterpillars for Cat-skiing
# 0                         NaN                               NaN
# 1                         NaN                               0.0
# 2                         NaN                               NaN
# 3                         NaN                               NaN
# 4                         NaN                               NaN

# %%
print(df['lat'].mean())
print(df['long'].mean())
# Out:
# 39.4470818182
# 106.208690909

# %%
help(px.scatter_mapbox)

df2 = df[['lat', 'long']]
# Out:
# Help on function scatter_mapbox in module plotly.express._chart_types:
#
# scatter_mapbox(data_frame, lat=None, lon=None, color=None, text=None, hover_name=None, hover_data=None, size=None, animation_frame=None, animation_group=None, category_orders={}, labels={}, color_discrete_sequence=None, color_discrete_map={}, color_continuous_scale=None, range_color=None, color_continuous_midpoint=None, opacity=None, size_max=None, zoom=8, title=None, template=None, width=None, height=None)
#         In a Mapbox scatter plot, each row of `data_frame` is represented by a symbol mark on a Mapbox map.
#
#     Arguments:
#         data_frame: A 'tidy' `pandas.DataFrame`
#         lat: (string: name of column in `data_frame`) Values from this column are used to position marks according to latitude on a map.
#         lon: (string: name of column in `data_frame`) Values from this column are used to position marks according to longitude on a map.
#         color: (string: name of column in `data_frame`) Values from this column are used to assign color to marks.
#         text: (string: name of column in `data_frame`) Values from this column appear in the figure as text labels.
#         hover_name: (string: name of column in `data_frame`) Values from this column appear in bold in the hover tooltip.
#         hover_data: (list of string: names of columns in `data_frame`) Values from these columns appear as extra data in the hover tooltip.
#         size: (string: name of column in `data_frame`) Values from this column are used to assign mark sizes.
#         animation_frame: (string: name of column in `data_frame`) Values from this column are used to assign marks to animation frames.
#         animation_group: (string: name of column in `data_frame`) Values from this column are used to provide object-constancy across animation frames: rows with matching `animation_group`s will be treated as if they describe the same object in each frame.
#         category_orders: (dict with string keys and list-of-string values, default `{}`) By default, in Python 3.6+, the order of categorical values in axes, legends and facets depends on the order in which these values are first encountered in `data_frame` (and no order is guaranteed by default in Python below 3.6). This parameter is used to force a specific ordering of values per column. The keys of this dict should correspond to column names, and the values should be lists of strings corresponding to the specific display order desired.
#         labels: (dict with string keys and string values, default `{}`) By default, column names are used in the figure for axis titles, legend entries and hovers. This parameter allows this to be overridden. The keys of this dict should correspond to column names, and the values should correspond to the desired label to be displayed.
#         color_discrete_sequence: (list of valid CSS-color strings) When `color` is set and the values in the corresponding column are not numeric, values in that column are assigned colors by cycling through `color_discrete_sequence` in the order described in `category_orders`, unless the value of `color` is a key in `color_discrete_map`. Various useful color sequences are available in the `plotly_express.colors` submodules, specifically `plotly_express.colors.qualitative`.
#         color_discrete_map: (dict with string keys and values that are valid CSS-color strings, default `{}`) Used to override `color_discrete_sequence` to assign a specific colors to marks corresponding with specific values. Keys in `color_discrete_map` should be values in the column denoted by `color`.
#         color_continuous_scale: (list of valid CSS-color strings) This list is used to build a continuous color scale when the column denoted by `color` contains numeric data. Various useful color scales are available in the `plotly_express.colors` submodules, specifically `plotly_express.colors.sequential`, `plotly_express.colors.diverging` and `plotly_express.colors.cyclical`.
#         range_color: (2-element list of numbers) If provided, overrides auto-scaling on the continuous color scale.
#         color_continuous_midpoint: (number, defaults to `None`) If set, computes the bounds of the continuous color scale to have the desired midpoint. Setting this value is recommended when using `plotly_express.colors.diverging` color scales as the inputs to `color_continuous_scale`.
#         opacity: (number, between 0 and 1) Sets the opacity for markers.
#         size_max: (integer, default 20) Set the maximum mark size when using `size`.
#         zoom: (integer between 0 and 20, default is 8) Sets map zoom level.
#         title: (string) The figure title.
#         template: (string or Plotly.py template object) The figure template name or definition.
#         width: (integer, default `None`) The figure width in pixels.
#         height: (integer, default `600`) The figure height in pixels.
#     Returns:
#         A `Figure` object.

# %%
haz13_custom_style = "mapbox://styles/shaz13/cjiog1iqa1vkd2soeu5eocy4i"

#set the geo=spatial data
import plotly.express as px
px.set_mapbox_access_token(MAPBOX_TOKEN)
carshare = px.data.carshare()
fig = px.scatter_mapbox(df2, lat="lat", lon="long",     color='lat', size='lat',
                  color_continuous_scale=px.colors.cyclical.IceFire, size_max=15, zoom=10)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-d1617cc8a11b> in <module>()
#       6 carshare = px.data.carshare()
#       7 fig = px.scatter_mapbox(df2, lat="lat", lon="long",     color='lat', size='lat',
# ----> 8                   color_continuous_scale=px.colors.cyclical.IceFire, size_max=15, zoom=10)
#       9 fig.show()
#
# /Users/andreyfilimonov/anaconda2/lib/python2.7/site-packages/plotly/express/_chart_types.pyc in scatter_mapbox(data_frame, lat, lon, color, text, hover_name, hover_data, size, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, color_continuous_scale, range_color, color_continuous_midpoint, opacity, size_max, zoom, title, template, width, height)
#     942     In a Mapbox scatter plot, each row of `data_frame` is represented by a symbol mark on a Mapbox map.
#     943     """
# --> 944     return make_figure(args=locals(), constructor=go.Scattermapbox)
#     945
#     946
#
# /Users/andreyfilimonov/anaconda2/lib/python2.7/site-packages/plotly/express/_core.pyc in make_figure(args, constructor, trace_patch, layout_patch)
#     991                 args, trace_spec, group, mapping_labels.copy(), sizeref
#     992             )
# --> 993             trace.update(patch)
#     994             if fit_results is not None:
#     995                 trendline_rows.append(mapping_labels.copy())
#
# /Users/andreyfilimonov/anaconda2/lib/python2.7/site-packages/plotly/basedatatypes.pyc in update(self, dict1, **kwargs)
#    3552                 BaseFigure._perform_update(self, kwargs)
#    3553         else:
# -> 3554             BaseFigure._perform_update(self, dict1)
#    3555             BaseFigure._perform_update(self, kwargs)
#    3556
#
# /Users/andreyfilimonov/anaconda2/lib/python2.7/site-packages/plotly/basedatatypes.pyc in _perform_update(plotly_obj, update_obj)
#    2750                     # Update compound objects recursively
#    2751                     # plotly_obj[key].update(val)
# -> 2752                     BaseFigure._perform_update(plotly_obj[key], val)
#    2753                 elif isinstance(validator, CompoundArrayValidator):
#    2754                     if plotly_obj[key]:
#
# /Users/andreyfilimonov/anaconda2/lib/python2.7/site-packages/plotly/basedatatypes.pyc in _perform_update(plotly_obj, update_obj)
#    2771                 else:
#    2772                     # Assign non-compound value
# -> 2773                     plotly_obj[key] = val
#    2774
#    2775         elif isinstance(plotly_obj, tuple):
#
# /Users/andreyfilimonov/anaconda2/lib/python2.7/site-packages/plotly/basedatatypes.pyc in __setitem__(self, prop, value)
#    3347             # ### Handle simple property ###
#    3348             else:
# -> 3349                 self._set_prop(prop, value)
#    3350
#    3351         # Handle non-scalar case
#
# /Users/andreyfilimonov/anaconda2/lib/python2.7/site-packages/plotly/basedatatypes.pyc in _set_prop(self, prop, val)
#    3630                 return
#    3631             else:
# -> 3632                 raise err
#    3633
#    3634         # val is None
#
# ValueError:
#     Invalid element(s) received for the 'size' property of scattermapbox.marker
#         Invalid elements include: [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]
#
#     The 'size' property is a number and may be specified as:
#       - An int or float in the interval [0, inf]
#       - A tuple, list, or one-dimensional numpy array of the above

# %%
pip install plotly.express
